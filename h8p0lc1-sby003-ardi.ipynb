# %%
# Variable membership

# LC_1-SBY003-ardi.ipynb

class konsumen:
    def __init__(self, name, price):
        self.name = name
        self.price = price

class membership:
    def __init__(self):
        self.items = []

    def add_item(self, name, price): # Input harga yang akan dimasukkan
        item = konsumen(name, price)
        self.items.append(item)
        print(f'Barang "{name}" yang dibayarkan.')

    def display_items(self): # Menampilkan harga yang sudah terinput
        print('Total di bayar:')
        for i, item in enumerate(self.items):
            print(f'{i}. {item.name} - Rp {item.price:.2f}')

    def calculate_discount_total(self): # Menampilkan total diskon membership
        total = sum(item.price for item in self.membership)
        for konsumen in self.konsumen:
                if membership = 'regular':
                    if total_harga > 10000:
                        diskon = 0.1  # Diskon 10% untuk total harga lebih dari Rp. 10.000
                    else:
                        diskon = 0.05  # Diskon 5% untuk total harga Rp. 10.000 atau kurang
                    return
       
                elif membership == 'VIP':
        
                    if total_harga > 50000:
                        diskon = 0.3  # Diskon 30% untuk total harga lebih dari Rp. 50.000
                    else:
                        diskon = 0.2  # Diskon 20% untuk total harga Rp. 50.000 atau kurang
                    else:
                        diskon = 0  # Tidak ada diskon untuk membership lainnya atau tidak ada membership
        
                    return


if __name__ == '__main__':
    membership_type = membership()
# Pilihan inputan yang akan dimasukkan dan akan ditampilkan
    while True:
        print("1. Menambah Harga")
        print("2. Tampilkan Harga")
        print("3. Lihat Total Harga")
        print("4. Exit")

        pilihan = input("Pilihan: ")

        if pilihan == '1':
            price = float(input("Masukkan harga: "))
            membership.add_item(price)

        elif pilihan == '2':
            membership.display_items()

        elif pilihan == '3':
            total = membership.calculate_total()
            print(f'Total harga: Rp {total:.2f} - total_diskon{membership}')

        elif pilihan == '4':
            print("Exit")
            break

        else:
            print("Pilihannya salah. Coba lagi.\n")


    def calculate_discount_total(self):
        total = sum(item.price for item in self.items)
        return
            
# Unit testing
prices_customer = []
result_customer = hitung_diskon(prices_customer, membership = ' ')
print(f"Customer type: \n Prices: {prices_customer}\n Expected result: 0\n Actual result: {result_customer} \n")

# import fuction

import unittest   

from membership_type import membership
class Test_add_item(unittest.TestCase):
